# %%
from scipy.io.wavfile import read

# %%
a = read('csv_data/009count_1.wav')

# %%
import numpy as np

# %%
np.array(a[1], dtype=np.float32)
# Out:
# array([[  0.,   0.],
#        [-13., -32.],
#        [  2.,   5.],
#        ...,
#        [400., 262.],
#        [430., 230.],
#        [463., 241.]], dtype=float32)

# %%
a[1].shape
# Out:
# (13122849, 2)

# %%
import glob
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import normalize

# %%
count = 0
for filename  in glob.iglob('csv_data/*.wav'):
    a = read(filename)
    print(a[1].shape)
    if count == 10:
        break
    count+=1
    x = a[1]/ np.linalg.norm(a[1])
    plt.plot(x)
    plt.ylabel('some numbers')
    plt.show()
# Out:
# (11259281, 2)
# (2531946, 2)
# (10660991, 2)
# (2646000, 2)
# (13122849, 2)
# (1814595, 2)
# (1814595, 2)
# (2436521, 2)
# (2436521, 2)
# (2436521, 2)
# (2436521, 2)

# %%
import sounddevice as sd

# %%
x = a[1]

# %%
x.shape
# Out:
# (2436521, 2)

# %%
x = np.delete(x, 0)

# %%
plt.plot(x)
plt.show()

# %%
x.shape
# Out:
# (4873041,)

# %%
sd.play(x, 44100)

# %%
plt.plot(x[x>=0])
plt.show()
